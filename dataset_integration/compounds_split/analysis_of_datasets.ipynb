# %%
import pandas as pd


dataset_no_stereo = pd.read_csv("../curated_dataset_no_stereochemistry_duplicates.csv")

dataset_stereo = pd.read_csv("../curated_dataset.csv")

# %%
from plants_sm.io.pickle import read_pickle

splits_08 = read_pickle("splits_compounds_08.pkl")
splits_06 = read_pickle("splits_compounds_06.pkl")
splits_04 = read_pickle("splits_compounds_04_corrected.pkl")
splits_02 = read_pickle("splits_compounds_02.pkl")

# %% [markdown]
# 20 %

# %%
train = splits_02[0][0]
validation = splits_02[0][1]
test = splits_02[0][2]
print("Dataset with no stereochemistry duplicates:")
print(f"Train: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(train)])}, \
      Validation: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(validation)])}, \
      Test: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(test)])}")
# Out:
# Dataset with no stereochemistry duplicates:
# Train: 45647,       Validation: 291,       Test: 6198

# %%
train = splits_02[0][0]
validation = splits_02[0][1]
test = splits_02[0][2]
print("Dataset")
print(f"Train: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(train)])}, \
      Validation: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(validation)])}, \
      Test: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(test)])}")
# Out:
# Dataset
# Train: 66213,       Validation: 294,       Test: 6723

# %% [markdown]
# 40%

# %%
train = splits_04[0][0]
validation = splits_04[0][1]
test = splits_04[0][2]
print("Dataset with no stereochemistry duplicates:")
print(f"Train: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(train)])}, \
      Validation: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(validation)])}, \
      Test: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(test)])}")
# Out:
# Dataset with no stereochemistry duplicates:
# Train: 43666,       Validation: 4704,       Test: 3766

# %%
train = splits_04[0][0]
validation = splits_04[0][1]
test = splits_04[0][2]
print("Dataset")
print(f"Train: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(train)])}, \
      Validation: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(validation)])}, \
      Test: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(test)])}")
# Out:
# Dataset
# Train: 63768,       Validation: 5237,       Test: 4225

# %% [markdown]
# 60%

# %%
train = splits_06[0][0]
validation = splits_06[0][1]
test = splits_06[0][2]
print("Dataset with no stereochemistry duplicates:")
print(f"Train: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(train)])}, \
      Validation: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(validation)])}, \
      Test: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(test)])}")
# Out:
# Dataset with no stereochemistry duplicates:
# Train: 37124,       Validation: 5367,       Test: 9645

# %%
train = splits_06[0][0]
validation = splits_06[0][1]
test = splits_06[0][2]
print("Dataset")
print(f"Train: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(train)])}, \
      Validation: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(validation)])}, \
      Test: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(test)])}")
# Out:
# Dataset
# Train: 56293,       Validation: 5836,       Test: 11101

# %% [markdown]
# 80%

# %%
train = splits_08[0][0]
validation = splits_08[0][1]
test = splits_08[0][2]
print("Dataset with no stereochemistry duplicates:")
print(f"Train: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(train)])}, \
      Validation: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(validation)])}, \
      Test: {len(dataset_no_stereo[dataset_no_stereo['Substrate ID'].isin(test)])}")
# Out:
# Dataset with no stereochemistry duplicates:
# Train: 34895,       Validation: 5974,       Test: 11267

# %%
train = splits_08[0][0]
validation = splits_08[0][1]
test = splits_08[0][2]
print("Dataset")
print(f"Train: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(train)])}, \
      Validation: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(validation)])}, \
      Test: {len(dataset_stereo[dataset_stereo['Substrate ID'].isin(test)])}")
# Out:
# Dataset
# Train: 50731,       Validation: 7495,       Test: 15004
