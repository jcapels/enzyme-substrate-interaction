# %%
import pandas as pd


dataset_no_stereo = pd.read_csv("../curated_dataset_no_stereochemistry_duplicates.csv")

dataset_stereo = pd.read_csv("../curated_dataset.csv")

# %%
from plants_sm.io.pickle import read_pickle

splits_04 = read_pickle("splits_0_4_proteins_train_val_test.pkl")
splits_06 = read_pickle("splits_0_6_proteins_train_val_test.pkl")
splits_08 = read_pickle("splits_0_8_proteins_train_val_test.pkl")

# %% [markdown]
# 40%

# %%
train = splits_04[0][0]
validation = splits_04[0][1]
test = splits_04[0][2]
print("Dataset with no stereochemistry duplicates:")
print(f"Train: {len(dataset_no_stereo[dataset_no_stereo['Enzyme ID'].isin(train)])}, \
      Validation: {len(dataset_no_stereo[dataset_no_stereo['Enzyme ID'].isin(validation)])}, \
      Test: {len(dataset_no_stereo[dataset_no_stereo['Enzyme ID'].isin(test)])}")
# Out:
# Dataset with no stereochemistry duplicates:
# Train: 39048,       Validation: 4181,       Test: 8907

# %%
train = splits_04[0][0]
validation = splits_04[0][1]
test = splits_04[0][2]
print("Dataset")
print(f"Train: {len(dataset_stereo[dataset_stereo['Enzyme ID'].isin(train)])}, \
      Validation: {len(dataset_stereo[dataset_stereo['Enzyme ID'].isin(validation)])}, \
      Test: {len(dataset_stereo[dataset_stereo['Enzyme ID'].isin(test)])}")
# Out:
# Dataset
# Train: 54690,       Validation: 5963,       Test: 12577

# %% [markdown]
# 60%

# %%
train = splits_06[0][0]
validation = splits_06[0][1]
test = splits_06[0][2]
print("Dataset with no stereochemistry duplicates:")
print(f"Train: {len(dataset_no_stereo[dataset_no_stereo['Enzyme ID'].isin(train)])}, \
      Validation: {len(dataset_no_stereo[dataset_no_stereo['Enzyme ID'].isin(validation)])}, \
      Test: {len(dataset_no_stereo[dataset_no_stereo['Enzyme ID'].isin(test)])}")
# Out:
# Dataset with no stereochemistry duplicates:
# Train: 35749,       Validation: 5413,       Test: 10974

# %%
train = splits_06[0][0]
validation = splits_06[0][1]
test = splits_06[0][2]
print("Dataset")
print(f"Train: {len(dataset_stereo[dataset_stereo['Enzyme ID'].isin(train)])}, \
      Validation: {len(dataset_stereo[dataset_stereo['Enzyme ID'].isin(validation)])}, \
      Test: {len(dataset_stereo[dataset_stereo['Enzyme ID'].isin(test)])}")
# Out:
# Dataset
# Train: 50220,       Validation: 7532,       Test: 15478

# %% [markdown]
# 80%

# %%
train = splits_08[0][0]
validation = splits_08[0][1]
test = splits_08[0][2]
print("Dataset with no stereochemistry duplicates:")
print(f"Train: {len(dataset_no_stereo[dataset_no_stereo['Enzyme ID'].isin(train)])}, \
      Validation: {len(dataset_no_stereo[dataset_no_stereo['Enzyme ID'].isin(validation)])}, \
      Test: {len(dataset_no_stereo[dataset_no_stereo['Enzyme ID'].isin(test)])}")
# Out:
# Dataset with no stereochemistry duplicates:
# Train: 36467,       Validation: 5241,       Test: 10428

# %%
train = splits_08[0][0]
validation = splits_08[0][1]
test = splits_08[0][2]
print("Dataset")
print(f"Train: {len(dataset_stereo[dataset_stereo['Enzyme ID'].isin(train)])}, \
      Validation: {len(dataset_stereo[dataset_stereo['Enzyme ID'].isin(validation)])}, \
      Test: {len(dataset_stereo[dataset_stereo['Enzyme ID'].isin(test)])}")
# Out:
# Dataset
# Train: 51159,       Validation: 7346,       Test: 14725
