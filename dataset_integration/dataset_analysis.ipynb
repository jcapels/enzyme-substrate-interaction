# %%
import pandas as pd

dataset = pd.read_csv("curated_dataset_no_stereochemistry_duplicates.csv")

# %%
dataset.Publication.value_counts()
# Out:
# https://doi.org/10.1073/pnas.1423570112              23544
# 10.1021/acschembio.7b00996                           10370
# https://doi.org/10.1038/s41467-023-38347-2            8717
# https://doi.org/10.1038/nchembio.1387                 2737
# 10.1021/acscentsci.9b00835                            2520
# https://doi.org/10.1038/s41589-018-0154-9             1995
# https://doi.org/10.1093/synbio/ysaa004                1095
# 10.1039/c4cc06021k                                     684
# https://pubs.acs.org/doi/10.1021/acscatal.0c01895      450
# https://doi.org/10.1002/prot.26019                      24
# Name: Publication, dtype: int64
