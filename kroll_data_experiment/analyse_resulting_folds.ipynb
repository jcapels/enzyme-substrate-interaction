# %%
import pandas as pd

pd.read_csv("binding_np_classifier.csv").sort_values(by="mcc validation set", ascending=False)
# Out:
#    Model type  Trial  F1_macro_validation_set  Precision validation set  \
# 12        gat     12                 0.783983                  0.778762
# 39        gat     39                 0.783915                  0.769255
# 46        gat     46                 0.782133                  0.777688
# 48        gat     48                 0.781690                  0.771458
# 49        gat     49                 0.781238                  0.769690
# 44        gat     44                 0.779573                  0.775209
# 14        gat     14                 0.780094                  0.759346
# 41        gat     41                 0.778589                  0.772122
# 31        gat     31                 0.779386                  0.763212
# 32        gat     32                 0.773555                  0.783181
# 35        gat     35                 0.775413                  0.772412
# 45        gat     45                 0.775409                  0.764099
# ...

# %%
import pandas as pd

dataset = pd.read_csv("train_dataset_w_representation_filtered.csv")

# %%
train = dataset[dataset["kfold_0"] == "train"]
valid = dataset[dataset["kfold_0"] == "valid"]
print("train", train.Binding.value_counts())
print("valid", valid.Binding.value_counts())
# Out:
# train 0.0    30034
# 1.0    10925
# Name: Binding, dtype: int64
# valid 0.0    7476
# 1.0    2725
# Name: Binding, dtype: int64

# %%
train = dataset[dataset["kfold_1"] == "train"]
valid = dataset[dataset["kfold_1"] == "valid"]
print("train", train.Binding.value_counts())
print("valid", valid.Binding.value_counts())
# Out:
# train 0.0    29940
# 1.0    10905
# Name: Binding, dtype: int64
# valid 0.0    7570
# 1.0    2745
# Name: Binding, dtype: int64

# %%
train = dataset[dataset["kfold_2"] == "train"]
valid = dataset[dataset["kfold_2"] == "valid"]
print("train", train.Binding.value_counts())
print("valid", valid.Binding.value_counts())
# Out:
# train 0.0    29858
# 1.0    10877
# Name: Binding, dtype: int64
# valid 0.0    7652
# 1.0    2773
# Name: Binding, dtype: int64

# %%
import pandas as pd 

pd.read_csv("binding_np_classifier.csv").sort_values(by="mcc validation set", ascending=False)
# Out:
#    Model type  Trial  F1_macro_validation_set  Precision validation set  \
# 13        gat     15                 0.808232                  0.826004
# 21        gat     23                 0.810150                  0.807496
# 28        gat     30                 0.809705                  0.800573
# 38        gat     40                 0.799691                  0.845934
# 10        gat     12                 0.799632                  0.802583
# 37        gat     39                 0.800146                  0.795224
# 11        gat     13                 0.796398                  0.799041
# 29        gat     31                 0.796353                  0.777855
# 14        gat     16                 0.794585                  0.783274
# 12        gat     14                 0.791796                  0.791651
# 31        gat     33                 0.791719                  0.778407
# 23        gat     25                 0.787104                  0.796400
# ...
