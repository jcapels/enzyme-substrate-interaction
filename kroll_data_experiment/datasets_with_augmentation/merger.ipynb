# %%
import pandas as pd

train = pd.read_csv("ESP_train_df.csv")
val = pd.read_csv("ESP_val_df.csv")
test = pd.read_csv("ESP_test_df.csv")

merged = pd.concat([train, val, test])
merged.to_csv("merged.csv", index=False)
