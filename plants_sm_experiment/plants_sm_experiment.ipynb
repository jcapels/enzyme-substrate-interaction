# %%
from rdkit.Chem import MolFromSmiles
from rdkit.Chem.Draw import MolToImage
MolToImage(MolFromSmiles("CC1(C)CCC[C@]2(C)[C@@H]3CC[C@](C)(CC3=CC[C@@H]12)C=C"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300 at 0x7FBD2BFCBCA0>
